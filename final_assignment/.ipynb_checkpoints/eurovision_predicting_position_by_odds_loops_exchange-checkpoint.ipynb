# %% [markdown]
# # Can odds predict the position of the finals of the Eurovision Songcontest right?
#
# ## Introduction
# // Some explanaition:
# - define the context,
# - the research question
# - and the practical relevance

# %% [markdown]
# ## Data preparation

# %% [markdown]
# // Some explanaition:
# - explain how you acquired the data,
# - and show your data cleaning steps

# %% [markdown]
# ### Retrieving Eurovision data by webscraping with Selenium

# %% [markdown]
# #### Eurovision data from 2015-2019

# %%
# Import libraries we need for webscraping and transformation to a json file
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import json

# %%
# Create a driver for webscraping
DRIVER_PATH = 'C:/Users/ninaj/Desktop/chromedriver_win32 (1)/chromedriver.exe' # !! !This is a local variable
driver = webdriver.Chrome(executable_path=DRIVER_PATH)

driver.maximize_window()
driver.get('https://google.com') # Get the driver from Google

# Set up options
options = Options()
options.headless = True
options.add_argument("--window-size=1920,1200")

# %%
# Define the years we're going to use. 2021 has been left out since 
#the URL for 2021 didn't inluce "-2021". Instead the year has been left empty. 
years = 2015, 2016, 2017, 2018, 2019

# %%
# Create a new empty array. We're going to fill this with Eurovsion data. 
data = []

# %%
# Create a for-loop to iterate through the years 2015-2019
for x in years:
    
    driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)
    
    # The Eurovsion URL with a variable (x) for the years 2015-2019
    driver.get("https://eurovisionworld.com/odds/eurovision-" + str(x)) 

    # Define the table where we need the data from. 
    numbers = driver.find_elements_by_xpath("//tbody/tr")
    

    # Iterate through the number of contestants. Each row from the table is one contestant
    for row in numbers:

        # Loop through all positions
        position_data = ""
        for position in row.find_elements_by_css_selector("td.opo"):
            position_data = position.text
        
        # Loop through all contestants
        contestant_data = ""
        for contestant in row.find_elements_by_css_selector("td.odt.odtl"):
            contestant_data = contestant.text
        
        # Loop through all the odd data (contestant and position included, will be removed later)
        odds_data = [odds.text for odds in row.find_elements_by_css_selector("td")]
        
        # Create a dictionary
        esf_all = {
            "contestant": contestant_data,
            "position": position_data,
            "odds": odds_data
            } 

        # Append the dictionary with Eurovsion data to the empty data array
        data.append(esf_all)
   
        # Create the JSON file
        with open("esf_data_2015_2019.json", "w", encoding='utf-8' ) as outfile:
            json.dump(data, outfile, ensure_ascii=False)


driver.close()

# %% [markdown]
# #### Eurovision data from 2021

# %%
driver = webdriver.Chrome(options=options, executable_path=DRIVER_PATH)

# Retrieve data from the URL for this year (2021)
driver.get("https://eurovisionworld.com/odds/eurovision")

# %%
# Define the table where we need the data from. 
numbers = driver.find_elements_by_xpath("//tbody/tr")

# Create a new empty array. We're going to fill this with Eurovsion data. 
data = []

# %%
# Iterate through the number of contestants
for row in numbers:
   
    # Loop through all the positions
    position_data = ""
    for position in row.find_elements_by_css_selector("td.opo"):
        position_data = position.text
       
   
    # Loop through all the contestants
    contestant_data = ""
    for contestant in row.find_elements_by_css_selector("td.odt.odtl"):
        contestant_data = contestant.text
    
    
    # Loop through all the odd data (contestant and position included, will be removed later)
    odds_data = [odds.text for odds in row.find_elements_by_css_selector("td")]
       
    # Create a dictionary
    esf_2021 = {
            "contestant": contestant_data,
            "position": position_data,
            "odds": odds_data
        } 

    # Append the dictionary with Eurovsion data to the empty data array
    data.append(esf_2021)
    
    # Create the JSON file
    with open("esf_data_2021.json", "w", encoding='utf-8' ) as outfile:
        json.dump(data, outfile, ensure_ascii=False)

        
driver.close()

# %% [markdown]
# ### Cleaning the Eurovision data

# %% [markdown]
# #### Eurovision data from 2015-2019

# %%
# Import the libraries we need to create a dataframe from the JSON files
import pandas as pd
import json

# %%
# Open the JSON file for the years 2015-2019
with open("esf_data_2015_2019.json", encoding='utf-8') as json_file:
    esf_data = json.load(json_file)

# %%
# Create a df for 2015-2019
df_esf = pd.DataFrame(esf_data)

# Skip the first row, which doesn't include any useful data
df_esf = df_esf.drop([0, 1])

# %%
x = 0
y = 2
array = ["BET365", "UNIBET", "YOU WIN", "BOYLE SPORTS", "CORAL", "SKY BET", "BET VICTOR", "TITAN BET", "PAF", "BETFAIR SPORT", "SPORTING BET", "INTERTOPS", "PADDY POWER", "BET FRED", "BETWAY", "STAN JAMES", "BWIN", "MATCHBOOK", "BETFAIR* EXCHANGE", "BETFAIR* EXCHANGE 2"]
while x < len(array):
    name = array[x]
    df_esf[name] = df_esf['odds'].str[y]

    x = x + 1
    y = y + 1

# %%
# Remove the odd column. We don't need this anymore.
del df_esf['odds']

# %% [markdown]
# I noticed the bet category names differ each year. Since we wanted to focus on the values of the bets, the names don't really matter. However, we want to exclude values which may cause problems in the prediction process. Therefore, it seems logical to remove the BETFAIR EXCHANGE values. Because some years have more/less bet categories, the BETFAIR EXCHANGE column position has been used to retrieve the extra columns for the bets. For example: 2016 has an extra bet category, BETFAIR EXCHANGE is filled with the values of the extra bet category. The actual BETFAIR EXCHANGE values are removed.

# %%
# Create df for 2015. Only final positions are included
df_2015 = df_esf.iloc[0:27].reset_index()
df_2015['year'] = 2015
# del df_2015['BETFAIR* EXCHANGE']
# del df_2015['BETFAIR* EXCHANGE 2']

# Create df for 2016. Only final positions are included
df_2016 = df_esf.iloc[29:55].reset_index()
df_2016['year'] = 2016
# del df_2016['BETFAIR* EXCHANGE 2']

# Create df for 2017. Only final positions are included
df_2017 = df_esf.iloc[57:83].reset_index()
df_2017['year'] = 2017
del df_2017['BET365']
# del df_2017['BETFAIR* EXCHANGE']
del df_2017['BETFAIR* EXCHANGE 2']

# Create df for 2018. Only final positions are included
df_2018 = df_esf.iloc[102:128].reset_index()
df_2018['year'] = 2018
del df_2018['BET365']
del df_2018['UNIBET']
# del df_2018['BETFAIR* EXCHANGE']
del df_2018['BETFAIR* EXCHANGE 2']

# Create df for 2019. Only final positions are included
df_2019 = df_esf.iloc[147:173].reset_index()
df_2019['year'] = 2019

# Add BETWAY for this year
del df_2019['BET365']
del df_2019['UNIBET']
# Remove the BET FAIR EXHANGES. These numbers have a larger range than the other odds, which can cause wrong assumptions later on. 
# del df_2019['BETFAIR* EXCHANGE 2']

# %%
# Remove the BET FAIR EXHANGES. These numbers have a larger range than the other odds, which can cause wrong assumptions later on. 
# del df_esf['BETFAIR* EXCHANGE']
# del df_esf['BETFAIR* EXCHANGE 2']

# %% [markdown]
# #### Eurovision data from 2021

# %%
# Open the JSON file for 2021
with open("esf_data_2021.json", encoding='utf-8') as json_file:
    esf_2015 = json.load(json_file)

# %%
# Create a df 
df_esf_2021 = pd.DataFrame(esf_2015)

# Skip the first row
df_esf_2021 = df_esf_2021.drop([0, 1])

# %%
# Show only the final positions
df_esf_2021 = df_esf_2021.iloc[0:26]

# %%
x = 0
y = 2
array = ["BET365", "UNIBET", "YOU WIN", "BOYLE SPORTS", "CORAL", "SKY BET", "BET VICTOR", "TITAN BET", "PAF", "BETFAIR SPORT", "SPORTING BET", "INTERTOPS", "PADDY POWER", "BET FRED", "BETWAY", "STAN JAMES", "BWIN", "MATCHBOOK", "BETFAIR* EXCHANGE", "BETFAIR* EXCHANGE 2"]
while x < len(array):
    name = array[x]
    df_esf_2021[name] = df_esf_2021['odds'].str[y]
    x = x + 1
    y = y + 1

# %%
# Remove the odd column
del df_esf_2021['odds']

# Remove the BET FAIR EXHANGES. These numbers have a larger range than the other odds, which can cause wrong assumptions later on. 
# del df_esf_2021['BETFAIR* EXCHANGE']

# %%
# Define the year in a column
df_esf_2021['year'] = 2021

# Generate an easier name
df_2021 = df_esf_2021
del df_2021['BET365']
del df_esf_2021['UNIBET']

# %% [markdown]
# ## Feature engineering
# // Calculations
# -  explain which transformations you have made to make your variables more informative (e.g., calculating number of days from a starting date)

# %% [markdown]
# ## Descriptive analysis
# // Graphs:
# - present relevant graphs, tables and numbers with respect to your problem

# %%
# Check if all dataframes are correct
df_2015.head(26)
# Out:
#     index                                         contestant position BET365  \
# 0       2                     Sweden Måns Zelmerlöw - Heroes        1    2.1
# 1       3          Russia Polina Gagarina - A Million Voices        2   3.75
# 2       4                       Italy Il Volo - Grande Amore        3      5
# 3       5                Belgium Loïc Nottet - Rhythm Inside        4     11
# 4       6            Australia Guy Sebastian - Tonight Again        5     11
# 5       7        Estonia Born & Rästa - Goodbye to Yesterday        6     19
# 6       8         Serbia Bojana Stamenov - Beauty Never Lies        7     34
# 7       9      Norway Mørland & Scarlett - A Monster Like Me        8     34
# 8      10            Latvia Aminata Savadogo - Love Injected        9     41
# 9      11                    Israel Nadav Guedj - Golden Boy       10     67
# 10     12       Azerbaijan Elnur Hüseynov - Hour Of The Wolf       11     67
# 11     13                            Spain Edurne - Amanecer       12     81
# 12     14                    Slovenia Maraaya - Here for You       13     81
# 13     15                    Georgia Nina Sublatti - Warrior       14    101
# 14     16     United Kingdom Velvet - Still in Love with You       15    151
# 15     17         Greece M. Elena Kyriakou - One Last Breath       16    151
# 16     18      Romania Voltaj - De La Capăt / All Over Again       17    151
# 17     19                Armenia Genealogy - Face The Shadow       18    151
# 18     20                   Albania Elhaida Dani - I'm Alive       19    151
# 19     21  Cyprus Karayiannis - One Thing I Should Have Done       20    151
# 20     22                  Hungary Boggie - Wars For Nothing       21    151
# 21     23                 France Lisa Angell - N’oubliez pas       22    151
# 22     24              Lithuania Monika & Vaidas - This Time       23    201
# 23     25          Poland M. Kuszyńska - In The Name Of Love       24    251
# 24     26                 Austria The Makemakes - I Am Yours       25    251
# 25     27                             Montenegro Knez - Adio       26    201
#
#    UNIBET YOU WIN BOYLE SPORTS CORAL SKY BET BET VICTOR  ... INTERTOPS  \
# 0       2    2.38         2.25   2.1     2.1        2.1  ...      2.25
# 1     4.5       4         3.75   4.5    3.75          4  ...         4
# 2       6       5            5   5.5     5.5          6  ...      4.25
# 3      12       9           12     9      10         12  ...         7
# 4      12       9           11    10      11         13  ...         9
# 5      24      34           23    21      21         19  ...        23
# 6      30      41           26    26      34         34  ...        29
# 7      30      41           34    41      41         41  ...        29
# 8      51      34           41    51      41         41  ...        34
# 9      51      67           81    41      67         46  ...        51
# 10     34      67           41    67      51         67  ...        51
# 11     34      81           51    67      81         67  ...        51
# 12     51      81           67    81      67         67  ...        51
# 13     81     151           67   101     101        101  ...        81
# 14    101     151          126    41     126         81  ...        81
# 15     81     126          101   126     101        126  ...       101
# 16    126     151          101   151     101        101  ...       126
# 17    101     151          176   151     151        151  ...       126
# 18    101     126          126   101     151        101  ...       101
# 19    126     151          101   151     126        126  ...       101
# 20    101     126          126   126     126        151  ...       101
# 21    126     126          176   151     126        126  ...       126
# 22    151     201          151   201     151        151  ...       126
# 23    251     251          151   251     201        151  ...       151
# 24    201     251          151   251     151        126  ...       151
# 25    101     251          151   251     251        201  ...       151
#
#    PADDY POWER BET FRED BETWAY STAN JAMES  BWIN MATCHBOOK BETFAIR* EXCHANGE  \
# 0            2        2    2.1       2.25     1      2.21               2.2
# 1            4      4.5      4        3.5  4.75      5.16              4.99
# 2          5.5      6.5    4.5        4.5     5      6.74              6.51
# 3            9       13      8          5    15        18                18
# 4           10       13     11          9    13        16                17
# 5           17       26     26         15    21        27                27
# 6           26       41     34         21    26        51                52
# 7           29       51     34         34              70                62
# 8           41       67     34         34             150               143
# 9           41       67     51         41    34                         133
# 10          51       67     51         41    51       100               105
# 11          81       67     67         51    51                         181
# 12          67       67     67         51    67       199               200
# 13          67      101     81         51    67       199               285
# 14          41      101    101         67   101       298               304
# 15          81      101    101        101   101                         703
# 16         101      101    126        101   101                         789
# 17         101      101    126        126   101       199               228
# 18         101      101    101        101   101       496               950
# 19         101      101    101        101   101       496               713
# 20         101      101    126         81   201       496               589
# 21         151      101    126        101   201       496               694
# 22         101      101    126        101   101       496               950
# 23         101      101    151        151   101                         903
# 24         151      101    151        101   101       496               950
# 25         151      101    151        176   101       496               950
#
#    BETFAIR* EXCHANGE 2  year
# 0                  NaN  2015
# 1                  NaN  2015
# 2                  NaN  2015
# 3                  NaN  2015
# 4                  NaN  2015
# 5                  NaN  2015
# 6                  NaN  2015
# 7                  NaN  2015
# 8                  NaN  2015
# 9                  NaN  2015
# 10                 NaN  2015
# 11                 NaN  2015
# 12                 NaN  2015
# 13                 NaN  2015
# 14                 NaN  2015
# 15                 NaN  2015
# 16                 NaN  2015
# 17                 NaN  2015
# 18                 NaN  2015
# 19                 NaN  2015
# 20                 NaN  2015
# 21                 NaN  2015
# 22                 NaN  2015
# 23                 NaN  2015
# 24                 NaN  2015
# 25                 NaN  2015
#
# [26 rows x 24 columns]

# %%
df_2016.head(27)
# Out:
#     index                                         contestant position BET365  \
# 0      31       Russia Sergey Lazarev - You Are the Only One        1    1.9
# 6     110    Lithuania I. Zasimauskaitė - When We're Old        7      51
# 7     111                   United Kingdom SuRie - Storm        8      51
# 8     112     Norway Rybak - That's How You Write a Song        9      81
# 9     113                 France Madame Monsieur - Mercy       10     101
# 10    114  Italy Meta & Moro - Non Mi Avete Fatto Niente       11     101
# 11    115         Australia Jessica Mauboy - We Got Love       12     101
# 12    116                 Finland Saara Aalto - Monsters       13     101
# 13    117       Czech Republic Mikolas Josef - Lie To Me       14     101
# 14    118                 Moldova DoReDos - My Lucky Day       15     101
# 15    119                       Bulgaria Equinox - Bones       16     201
# 16    120              Denmark Rasmussen - Higher Ground       17     201
# 17    121                     Hungary AWS - Viszlát Nyár       18     176
# 18    122             Netherlands Waylon - Outlaw In 'Em       19     201
# 19    123         Austria Cesár Sampson - Nobody But You       20     301
# 20    124             Ukraine Mélovin - Under the Ladder       21     401
# 21    125              Spain Amaia & Alfred - Tu Canción       22     501
# 22    126            Portugal Cláudia Pascoal - O Jardim       23     751
# 23    127                 Albania Eugent Bushpepa - Mall       24     501
# 24    128                 Slovenia Lea Sirk - Hvala, ne!       25    1001
# 25    129      Serbia Sanja Ilić & Balkanika - Nova Deca       26    1001
#
#    BOYLE SPORTS CORAL SKY BET BET VICTOR TITAN BET  PAF  ... SPORTING BET  \
# 0           2.1   2.2    2.15        2.2      2.25    2  ...          2.1
# 1          3.75     4     3.6        3.5      3.25  3.4  ...          3.2
# 2            23    26     8.5        6.5         7  7.5  ...            7
# 3             8     8      19         13        15   17  ...           15
# 4            31    29      26         26        21   26  ...           26
# 5            21    26      40         41        34   51  ...           41
# 6            23    21      55         41        41   34  ...           41
# 7           201    51      41         34        21   51  ...           41
# 8            29    34      60         81        41   67  ...           41
# 9            16    17      60         51        67   51  ...           67
# 10           23    21      70         41        81   67  ...           81
# 11           39    51      75         67        51  101  ...           71
# 12           51    41      50        101        51  101  ...           67
# 13           51    51      75         81        67   67  ...           76
# 14           51    51      65        101       101  101  ...          101
# 15           51    51     120        151        67   67  ...          126
# 16           67    67     130        151       126  101  ...          101
# 17           67    67     130        151       101  101  ...          151
# 18          126   151     150        151       151  201  ...          151
# 19          101   151     150        251       101  101  ...          126
# 20          126   101     240        501       101  201  ...           81
# 21          101   151     220        501       151  201  ...          201
# 22          151   151     300        501       201  301  ...          201
# 23          201   201     500        501       301  301  ...          201
# 24          301   201     350        501       301  301  ...          401
# 25          401   201     500        501       501  301  ...          301
#
#    INTERTOPS PADDY POWER BET FRED BETWAY STAN JAMES  BWIN MATCHBOOK  \
# 0        2.1         2.2     2.25    2.2       2.25   2.2      2.38
# 1        3.1        3.25     3.25   3.25        3.5  3.25      3.25
# 2          8         6.5        8    6.5        6.5     7         8
# 3         18          12       18     12         15    15        15
# 4         25          26       33     26         34    21        26
# 5         35          34       36     34         34    29        34
# 6         30          34       41     34         41    41        41
# 7         50          19       31     19         11    29        17
# 8         35          51       41     51         51    41        67
# 9         50          51       51     51         41    51        67
# 10        25          51       71     51         51    41        51
# 11        75          29       61     29         51    51        67
# 12        50          67       61     67         81    51        67
# 13        70          67       51     67         51    67       101
# 16                  Azerbaijan Efendi - Mata Hari       15     101
# 17                   Greece Stefania - Last Dance       16     201
# 18                 Russia Manizha - Russian Woman       17     251
# 19                   Serbia Hurricane - Loco Loco       18     501
# 20                Israel Eden Alene - Set Me Free       19     501
# 21    Netherlands J. Macrooy - Birth Of A New Age       20     201
# 22         Belgium Hooverphonic - The Wrong Place       21     751
# 23           United Kingdom James Newman - Embers       22     751
# 24              Moldova Natalia Gordienko - Sugar       23     751
# 25            Germany Jendrik - I Don't Feel Hate       24     501
# 26              Spain Blas Cantó - Voy A Quedarme       25     751
# 27              Albania Anxhela Peristeri - Karma       26     751
#
#    BOYLE SPORTS CORAL SKY BET BET VICTOR TITAN BET   PAF BETFAIR SPORT  ...  \
# 2           2.8  3.25    3.25       2.75       3.5   3.4          2.65  ...
# 3           4.5  3.25    3.25        4.5         4     3           4.3  ...
# 4             6   4.5       5        5.5         5  4.75           5.1  ...
# 5             8    11      18          8        17    12            12  ...
# 6            16     9      11         21        13    11           8.5  ...
# 7            11    17      18         11        17    21            15  ...
# 8            16    21      21         17        17    21            18  ...
# 9            61    41      51         61        41    41            34  ...
# 10           56    41      51         91        41    41            50  ...
# 11           46    41      81         67        81    81            65  ...
# 12           81    67      81        126        67    51            50  ...
# 13           41    81      81         51       101    81            45  ...
# 14           61    81     101        101       101   101            90  ...
# 15           61   126     151        111       151   101            80  ...
# 16          126   101     126        201       101   126           150  ...
# 17          126   176     151        201       151   151           150  ...
# 18          126   151     151        201       251   126           150  ...
# 19          151   251     201        151       351   201           150  ...
# 20          251   251     251        301       351   251           250  ...
# 21          401   251     501        501       251   401           300  ...
# 22          401   251     251        501       601   301           300  ...
# 23          301   201     501        301       601   751           500  ...
# 24          401   251     501        501       601   501           250  ...
# 25          501   401     501        501       351   751           400  ...
# 26          501   251     501        501       601   751           350  ...
# 27          501   501     501        501       601   501           250  ...
#
#    INTERTOPS PADDY POWER BET FRED BETWAY STAN JAMES  BWIN MATCHBOOK  \
# 2       3.25         2.8        3      3        3.4   3.5       3.5
# 3        3.5        4.25      4.5    3.5          4   3.5         4
# 4        4.5           6      5.5      5          5     5       4.5
# 5         11           8        8     12         13    17        15
# 6         11          14       26     10         13     9        11
# 7         15          11       12     16         19    13        17
# 8         15          16       19     16         17    17        17
# 9         34          49       67     50         34    26        34
# 10        26          56       67     25         26    17        26
# 11        51          46       67     50         34    81        34
# 12        51          49      101     50         67    34        51
# 13       101          41       51     75         67   101        51
# 14        67          61       67     75         41   101       101
# 15       101          61       67     75         81    51       101
# 16       151         126      101    100         81   151       101
# 17       151         126      101     75        151   151       101
# 18       201         126      101    100        151   151       101
# 19       201         111      101    100        151   101       101
# 20       251         251      101    100        201   101       101
# 21       251         401      501    250        151   101       126
# 22       501         401      301    100        201   251       126
# 23       251         301      501    100         67   101       101
# 24       501         401      301    100        201   301       126
# 25       201         451      501    250        251   301       126
# 26       501         501      501    250        251   501       126
# 27       501         501      501    250        251  1001       126
#
#    BETFAIR* EXCHANGE BETFAIR* EXCHANGE 2  year
# 2               3.55                3.24  2021
# 3               3.95                 4.5  2021
# 4                5.3                   5  2021
# 5                 19                  26  2021
# 6                 16                  67  2021
# 7                 19                  19  2021
# 8                 18                  13  2021
# 9                 46                  34  2021
# 10                50                  67  2021
# 11                90                  26  2021
# 12                90                 101  2021
# 13               130                 151  2021
# 14               150                  17  2021
# 15               180                  11  2021
# 16               140                 101  2021
# 17               260                  67  2021
# 18               290                  51  2021
# 19               300                 301  2021
# 20               300                 101  2021
# 21               280                 501  2021
# 22               500                 101  2021
# 23               500                 151  2021
# 24               500                 101  2021
# 25               300                 151  2021
# 26               500                 501  2021
# 27               500                 501  2021
#
# [26 rows x 21 columns]

# %%
# Append the dataframes

# %% [markdown]
# The dataframes exist of the following values:
# - The country, artist name and song title
# - The final position
# - At least 16 columns of bet categories. The lower the odds, the less money you win and the higher the chance of winning the Eurovision Songcontest.
# - The year of the song contest

# %% [markdown]
# #### Define the y variable and X variables

# %%
# esf_years = 2015, 2016, 2017, 2018, 2019, 2021
# for x in esf_years:
#     print('X_odds_'+str(x))

# %%
# Select X and y variables for each year

# 2015

X_odds_2015 = df_2015.iloc[:, 3:22] 
# Make sure all Eurovision years have the same length
X_odds_2015.iloc[0:28]

y_odds_2015 = df_2015['position']

# Make sure all Eurovision years have the same length
y_odds_2015.iloc[0:27]
# print('2015')
# print(X_odds_2015)
# print(y_odds_2015)



# 2016

X_odds_2016 = df_2016.iloc[:, 3:22] 
# Make sure all Eurovision years have the same length
X_odds_2016.iloc[0:27]

y_odds_2016 = df_2016['position']
# Make sure all Eurovision years have the same length
y_odds_2016.iloc[0:27]

# print('2016')
# print(X_odds_2016)
# print(y_odds_2016)

# 2017

X_odds_2017 = df_2017.iloc[:, 3:21] 
# Make sure all Eurovision years have the same length
X_odds_2017.iloc[0:27]

y_odds_2017 = df_2017['position']
# Make sure all Eurovision years have the same length
y_odds_2017.iloc[0:27]

# print('2017')
# print(X_odds_2017)
# print(y_odds_2017)

# 2018

X_odds_2018 = df_2018.iloc[:, 3:20] 
# Make sure all Eurovision years have the same length
X_odds_2018.iloc[0:27]

y_odds_2018 = df_2018['position']
# Make sure all Eurovision years have the same length
y_odds_2018.iloc[0:27]
# print('2018')
# print(X_odds_2018)
# print(y_odds_2018)

# 2019

X_odds_2019 = df_2019.iloc[:, 3:21] 
# Make sure all Eurovision years have the same length
X_odds_2019.iloc[0:27]

y_odds_2019 = df_2019['position']
# Make sure all Eurovision years have the same length
y_odds_2019.iloc[0:27]
# print('2019')
# print(X_odds_2019)
# print(y_odds_2019)

# 2021

X_odds_2021 = df_2021.iloc[:, 2:20] 
# Make sure all Eurovision years have the same length
X_odds_2021.iloc[0:27]
                 
y_odds_2021 = df_2021['position']
# Make sure all Eurovision years have the same length
y_odds_2021.iloc[0:27]
# print('2021')
# print(X_odds_2021)
# print(y_odds_2021)
# Out:
# 2      1
# 3      2
# 4      3
# 5      4
# 6      5
# 7      6
# 8      7
# 9      8
# 10     9
# 11    10
# 12    11
# 13    12
# 14    13
# 15    14
# 16    15
# 17    16
# 18    17
# 19    18
# 20    19
# 21    20
# 22    21
# 23    22
# 24    23
# 25    24
# 26    25
# 27    26
# Name: position, dtype: object

# %%
# Import the numpy library for datatype transformations
import numpy as np

# %% [markdown]
# #### Transform Eurovision data 2015

# %%
# Transform empty values 
X_odds_2015  = X_odds_2015.replace('', np.nan_to_num(0), regex=True)

# As float
X_odds_2015.iloc[:, 0:19] = X_odds_2015.iloc[:, 0:19].astype(float)
y_odds_2015 = y_odds_2015.astype(float)

# print(X_odds_2015, y_odds_2015)

# %% [markdown]
# In order to decrease the range of values, we can use the log of the odd values.

# %%
# Transform odds into log 
X_odds_2015_log = np.log(X_odds_2015.iloc[:, 0:19])
# print(X_odds_2015_log)
X_odds_2015_log[~X_odds_2015_log.isin([np.nan, np.inf, -np.inf]).any(1)] # Remove inf
# Out:
# C:\Users\ninaj\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in log
#       BET365    UNIBET   YOU WIN  BOYLE SPORTS     CORAL   SKY BET  \
# 0   0.741937  0.693147  0.867100      0.810930  0.741937  0.741937
# 1   1.321756  1.504077  1.386294      1.321756  1.504077  1.321756
# 2   1.609438  1.791759  1.609438      1.609438  1.704748  1.704748
# 3   2.397895  2.484907  2.197225      2.484907  2.197225  2.302585
# 4   2.397895  2.484907  2.197225      2.397895  2.302585  2.397895
# 5   2.944439  3.178054  3.526361      3.135494  3.044522  3.044522
# 6   3.526361  3.401197  3.713572      3.258097  3.258097  3.526361
# 10  4.204693  3.526361  4.204693      3.713572  4.204693  3.931826
# 12  4.394449  3.931826  4.394449      4.204693  4.394449  4.204693
# 13  4.615121  4.394449  5.017280      4.204693  4.615121  4.615121
# 14  5.017280  4.615121  5.017280      4.836282  3.713572  4.836282
# 17  5.017280  4.615121  5.017280      5.170484  5.017280  5.017280
# 18  5.017280  4.615121  4.836282      4.836282  4.615121  5.017280
# 19  5.017280  4.836282  5.017280      4.615121  5.017280  4.836282
# 20  5.017280  4.615121  4.836282      4.836282  4.836282  4.836282
# 21  5.017280  4.836282  4.836282      5.170484  5.017280  4.836282
# 22  5.303305  5.017280  5.303305      5.017280  5.303305  5.017280
# 24  5.525453  5.303305  5.525453      5.017280  5.525453  5.017280
# 25  5.303305  4.615121  5.525453      5.017280  5.525453  5.525453
#
#     BET VICTOR  TITAN BET       PAF  BETFAIR SPORT  SPORTING BET  INTERTOPS  \
# 0     0.741937   0.741937  0.810930       0.741937      0.693147   0.810930
# 1     1.386294   1.386294  1.252763       1.386294      1.386294   1.386294
# 2     1.791759   1.704748  1.609438       1.791759      1.609438   1.446919
# 3     2.484907   2.302585  2.014903       2.079442      2.397895   1.945910
# 4     2.564949   2.302585  2.302585       2.397895      2.397895   2.197225
# 5     2.944439   3.044522  3.367296       2.833213      3.044522   3.135494
# 6     3.526361   3.367296  3.367296       3.258097      3.526361   3.367296
# 10    4.204693   4.204693  3.526361       4.204693      3.713572   3.931826
# 12    4.204693   4.394449  3.931826       4.394449      4.204693   3.931826
# 13    4.615121   4.394449  4.394449       4.394449      4.615121   4.394449
# 14    4.394449   4.394449  4.615121       4.394449      4.394449   4.394449
# 17    5.017280   5.017280  4.615121       4.615121      4.615121   4.836282
# 18    4.615121   4.836282  4.615121       4.615121      4.615121   4.615121
# 19    4.836282   4.836282  4.836282       4.836282      4.615121   4.615121
# 20    5.017280   4.836282  4.615121       4.615121      4.615121   4.615121
# 21    4.836282   4.836282  4.836282       4.615121      4.615121   4.836282
# 22    5.017280   5.017280  5.017280       4.615121      4.615121   4.836282
# 24    4.836282   5.017280  5.303305       4.615121      5.017280   5.017280
# 25    5.303305   4.836282  4.615121       4.836282      5.303305   5.017280
#
#     PADDY POWER  BET FRED    BETWAY  STAN JAMES      BWIN  MATCHBOOK  \
# 0      0.693147  0.693147  0.741937    0.810930  0.000000   0.792993
# 1      1.386294  1.504077  1.386294    1.252763  1.558145   1.640937
# 2      1.704748  1.871802  1.504077    1.504077  1.609438   1.908060
# 3      2.197225  2.564949  2.079442    1.609438  2.708050   2.890372
# 4      2.302585  2.564949  2.397895    2.197225  2.564949   2.772589
# 5      2.833213  3.258097  3.258097    2.708050  3.044522   3.295837
# 6      3.258097  3.713572  3.526361    3.044522  3.258097   3.931826
# 10     3.931826  4.204693  3.931826    3.713572  3.931826   4.605170
# 12     4.204693  4.204693  4.204693    3.931826  4.204693   5.293305
# 13     4.204693  4.615121  4.394449    3.931826  4.204693   5.293305
# 14     3.713572  4.615121  4.615121    4.204693  4.615121   5.697093
# 17     4.615121  4.615121  4.836282    4.836282  4.615121   5.293305
# 18     4.615121  4.615121  4.615121    4.615121  4.615121   6.206576
# 19     4.615121  4.615121  4.615121    4.615121  4.615121   6.206576
# 20     4.615121  4.615121  4.836282    4.394449  5.303305   6.206576
# 21     5.017280  4.615121  4.836282    4.615121  5.303305   6.206576
# 22     4.615121  4.615121  4.836282    4.615121  4.615121   6.206576
# 24     5.017280  4.615121  5.017280    4.615121  4.615121   6.206576
# 25     5.017280  4.615121  5.017280    5.170484  4.615121   6.206576
#
#     BETFAIR* EXCHANGE
# 0            0.788457
# 1            1.607436
# 2            1.873339
# 3            2.890372
# 4            2.833213
# 5            3.295837
# 6            3.951244
# 10           4.653960
# 12           5.298317
# 13           5.652489
# 14           5.717028
# 17           5.429346
# 18           6.856462
# 19           6.569481
# 20           6.378426
# 21           6.542472
# 22           6.856462
# 24           6.856462
# 25           6.856462

# %% [markdown]
# #### Transform Eurovision data 2016

# %%
# Transform empty values 
X_odds_2016  = X_odds_2016.replace('', np.nan_to_num(0), regex=True)

# As float
X_odds_2016.iloc[:, 0:19] = X_odds_2016.iloc[:, 0:19].astype(float)
y_odds_2016 = y_odds_2016.astype(float)

# print(X_odds_2016, y_odds_2016)

# %% [markdown]
# #### Transform Eurovision data 2017

# %%
# Transform empty values 
X_odds_2017  = X_odds_2017.replace('', np.nan_to_num(0), regex=True)

# As float
X_odds_2017.iloc[:, 0:19] = X_odds_2017.iloc[:, 0:19].astype(float)
y_odds_2017 = y_odds_2017.astype(float)

# %% [markdown]
# #### Transform Eurovision data 2018

# %%
# Transform empty values 
X_odds_2018  = X_odds_2018.replace('', np.nan_to_num(0), regex=True)

# As float
X_odds_2018.iloc[:, 0:19] = X_odds_2018.iloc[:, 0:19].astype(float)
y_odds_2018 = y_odds_2018.astype(float)

# %% [markdown]
# #### Transform Eurovision data 2019

# %%
# Transform empty values 
X_odds_2019  = X_odds_2019.replace('', np.nan_to_num(0), regex=True)

# As float
X_odds_2019.iloc[:, 0:19] = X_odds_2019.iloc[:, 0:19].astype(float)
y_odds_2019 = y_odds_2019.astype(float)

# %% [markdown]
# #### Transform Eurovision data 2021

# %%
# Transform empty values 
X_odds_2021  = X_odds_2021.replace('', np.nan_to_num(0), regex=True)

# As float
X_odds_2021.iloc[:, 0:19] = X_odds_2021.iloc[:, 0:19].astype(float)
y_odds_2021 = y_odds_2021.astype(float)

# %% [markdown]
# ## Predictive model
# // Explanaition
# - explain which analysis you have chosen and why. In which you build a relevant statistical model or train a machine learning algorithm.

# %% [markdown]
# We need to split the data into a train and test set in order to train the model before creating a realistic prediction (test data).
#
# The prediction will be based on the Random Forest Regressor algorithm. Because the predicted value is not classified, but an actual value with variance, we're going to use the **Random Forest Regressor**.

# %% [markdown]
# ### Train the model for 2015

# %%
# The libraries we need to import for predictions
import seaborn as sns
import sklearn as sk
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split # We need this to split the data
from sklearn.preprocessing import normalize # We need this to normalize our data
from sklearn.ensemble import RandomForestRegressor # We need this to use the Random Forest Regressor
from sklearn.metrics import confusion_matrix # We need this to make a confusion matrix
from sklearn.metrics import classification_report # We need this to calculate the accuracy, precision and recall

# %%
# Create a for loop to iterate through all the years

# %%
# Define X and y variables
X15 = X_odds_2015
y15 = y_odds_2015

X15_train, X15_test, y15_train, y15_test = train_test_split(X15, y15, test_size=0.3, random_state=1) #split the data, store it into different variables
X15_train.head()
# Out:
#     BET365  UNIBET  YOU WIN  BOYLE SPORTS  CORAL  SKY BET  BET VICTOR  \
# 2      5.0     6.0      5.0           5.0    5.5      5.5         6.0
# 22   201.0   151.0    201.0         151.0  201.0    151.0       151.0
# 6     34.0    30.0     41.0          26.0   26.0     34.0        34.0
# 19   151.0   126.0    151.0         101.0  151.0    126.0       126.0
# 13   101.0    81.0    151.0          67.0  101.0    101.0       101.0
#
#     TITAN BET    PAF  BETFAIR SPORT  SPORTING BET  INTERTOPS  PADDY POWER  \
# 2         5.5    5.0            6.0           5.0       4.25          5.5
# 22      151.0  151.0          101.0         101.0     126.00        101.0
# 6        29.0   29.0           26.0          34.0      29.00         26.0
# 19      126.0  126.0          126.0         101.0     101.00        101.0
# 13       81.0   81.0           81.0         101.0      81.00         67.0
#
#     BET FRED  BETWAY  STAN JAMES   BWIN  MATCHBOOK  BETFAIR* EXCHANGE
# 2        6.5     4.5         4.5    5.0       6.74               6.51
# 22     101.0   126.0       101.0  101.0     496.00             950.00
# 6       41.0    34.0        21.0   26.0      51.00              52.00
# 19     101.0   101.0       101.0  101.0     496.00             713.00
# 13     101.0    81.0        51.0   67.0     199.00             285.00

# %% [markdown]
# Random Forest Regressor will be trained with 100 trees. The model will predict the y variable; the position.

# %% [markdown]
# ### <font color='green'>Random forest

# %%
# TRAIN THE MODEL
rf15 = RandomForestRegressor(random_state=1, n_estimators=100) #RF is a random algorithm, so to get the same results we need to use random_state
rf15 = rf15.fit(X15_train, y15_train)

# %% [markdown]
# ### <font color="orange">K-nearest neighbor

# %%
from sklearn.neighbors import KNeighborsRegressor #the object class we need

knn15 = KNeighborsRegressor(n_neighbors=5) #create a KNN-classifier with 5 neighbors (default)
knn15 = knn15.fit(X15_train, y15_train) #this fits the k-nearest neigbor model with the train data

# %% [markdown]
# ### <font color="purple">Refine with log

# %%
# # Define X and y variables
# X15L = X_odds_2015_log.astype(np.float32)
# y15L = y_odds_2015

# X15L_train, X15L_test, y15L_train, y15L_test = train_test_split(X15L, y15L, test_size=0.3, random_state=1) #split the data, store it into different variables
# X15L_train.head()

# %%
# TRAIN THE MODEL
# rf15L = RandomForestRegressor(random_state=1, n_estimators=100) #RF is a random algorithm, so to get the same results we need to use random_state
# rf15L = rf15L.fit(X15_train, y15L_train)

# %%
# from sklearn.neighbors import KNeighborsRegressor #the object class we need

# knn15 = KNeighborsRegressor(n_neighbors=5) #create a KNN-classifier with 5 neighbors (default)
# knn15 = knn15.fit(X15_train, y15_train) #this fits the k-nearest neigbor model with the train data

# %% [markdown]
# ### Train the model for 2016

# %%
# Define X and y variables
X16 = X_odds_2016
y16 = y_odds_2016

X16_train, X16_test, y16_train, y16_test = train_test_split(X16, y16, test_size=0.3, random_state=1) #split the data, store it into different variables
X16_train.head()
# Out:
#     BET365  UNIBET  YOU WIN  BOYLE SPORTS  CORAL  SKY BET  BET VICTOR  \
# 4     17.0    34.0     26.0          51.0   51.0     16.0        34.0
# 2     10.0    17.0     17.0          19.0   26.0     15.0        13.0
# 21   201.0   501.0    501.0         301.0  201.0    151.0       501.0
# 6     29.0    41.0     51.0          67.0   67.0     36.0        51.0
# 14    67.0   151.0    201.0         201.0  201.0     51.0       251.0
#
#     TITAN BET    PAF  BETFAIR SPORT  SPORTING BET  INTERTOPS  PADDY POWER  \
# 4        15.0   21.0          15.00          29.0       26.0         18.0
# 2        10.0   10.0           8.75          19.0       13.0         11.0
# 21      201.0  301.0         226.00         201.0      201.0        200.0
# 6        41.0   41.0          31.00          51.0       34.0         25.0
# 14       71.0  151.0          71.00         101.0      101.0         65.0
#
#     BET FRED  BETWAY  STAN JAMES   BWIN  MATCHBOOK  BETFAIR* EXCHANGE
# 4       16.0    17.0        21.0   26.0       19.0               15.0
# 2       15.0    10.0        17.0   15.0       15.0                9.0
# 21     151.0   151.0       201.0  101.0      101.0              151.0
# 6       36.0    34.0        67.0   34.0       34.0               26.0
# 14      51.0    51.0       101.0  101.0       67.0               51.0

# %%
# TRAIN THE MODEL
rf16 = RandomForestRegressor(random_state=1, n_estimators=100) #RF is a random algorithm, so to get the same results we need to use random_state
rf16 = rf16.fit(X16_train, y16_train)

# %%
# K-Nearest neighbor
from sklearn.neighbors import KNeighborsRegressor #the object class we need

knn16 = KNeighborsRegressor(n_neighbors=5) #create a KNN-classifier with 5 neighbors (default)
knn16 = knn16.fit(X16_train, y16_train) #this fits the k-nearest neigbor model with the train data

# %% [markdown]
# ### Train the model for 2017

# %%
# Define X and y variables
X17 = X_odds_2017
y17 = y_odds_2017

X17_train, X17_test, y17_train, y17_test = train_test_split(X17, y17, test_size=0.3, random_state=1) #split the data, store it into different variables
X17_train.head()
# Out:
#     UNIBET  YOU WIN  BOYLE SPORTS  CORAL  SKY BET  BET VICTOR  TITAN BET  \
# 4     19.0    34.00          26.0   19.0     17.0        18.0       15.0
# 2      6.5     2.75           3.0    8.0      7.0         8.0        9.0
# 21   501.0   251.00         201.0  301.0    401.0       300.0      251.0
# 6     51.0    51.00          51.0   26.0     51.0        40.0       26.0
# 14   301.0   126.00         101.0   81.0    301.0        60.0      201.0
#
#       PAF  BETFAIR SPORT  SPORTING BET  INTERTOPS  PADDY POWER  BET FRED  \
# 4    20.0           17.0          17.0       17.0         17.0      15.0
# 2     7.5            8.0           7.5        7.5          8.0       9.0
# 21  300.0          201.0         201.0      201.0        251.0     251.0
# 6    40.0           51.0          34.0       34.0         29.0      26.0
# 14  100.0          201.0         251.0      251.0        201.0     201.0
#
#     BETWAY  STAN JAMES   BWIN  MATCHBOOK  BETFAIR* EXCHANGE
# 4     13.0        26.0   17.0      26.00               23.0
# 2      8.0         7.0    7.0       2.88                9.0
# 21   101.0       101.0  201.0     201.00             1000.0
# 6     26.0        51.0   41.0      61.00               75.0
# 14   101.0       101.0  151.0       0.00              670.0

# %%
# TRAIN THE MODEL
rf17 = RandomForestRegressor(random_state=1, n_estimators=100) #RF is a random algorithm, so to get the same results we need to use random_state
rf17 = rf17.fit(X17_train, y17_train)

# %%
# K-Nearest neighbor
from sklearn.neighbors import KNeighborsRegressor #the object class we need

knn17 = KNeighborsRegressor(n_neighbors=5) #create a KNN-classifier with 5 neighbors (default)
knn17 = knn16.fit(X17_train, y17_train) #this fits the k-nearest neigbor model with the train data

# %% [markdown]
# ### Train the model for 2018

# %%
# Define X and y variables
X18 = X_odds_2018
y18 = y_odds_2018

X18_train, X18_test, y18_train, y18_test = train_test_split(X18, y18, test_size=0.3, random_state=1) #split the data, store it into different variables
X18_train.head()
# Out:
#     YOU WIN  BOYLE SPORTS  CORAL  SKY BET  BET VICTOR  TITAN BET    PAF  \
# 4      34.0          31.0   29.0     26.0        26.0       21.0   26.0
# 2       7.5          23.0   26.0      8.5         6.5        7.0    7.5
# 21    501.0         101.0  151.0    220.0       501.0      151.0  201.0
# 6      51.0          23.0   21.0     55.0        41.0       41.0   34.0
# 14    101.0          51.0   51.0     65.0       101.0      101.0  101.0
#
#     BETFAIR SPORT  SPORTING BET  INTERTOPS  PADDY POWER  BET FRED  BETWAY  \
# 4            33.0          26.0       25.0         26.0      33.0    26.0
# 2             8.0           7.0        8.0          6.5       8.0     6.5
# 21          101.0         201.0      125.0        151.0     101.0   151.0
# 6            41.0          41.0       30.0         34.0      41.0    34.0
# 14           51.0         101.0       50.0         67.0      51.0    67.0
#
#     STAN JAMES   BWIN  MATCHBOOK  BETFAIR* EXCHANGE
# 4         34.0   21.0       26.0               38.0
# 2          6.5    7.0        8.0                8.4
# 21       251.0  151.0      101.0             1000.0
# 6         41.0   41.0       41.0               70.0
# 14        81.0   51.0       67.0              140.0

# %%
# TRAIN THE MODEL
rf18 = RandomForestRegressor(random_state=1, n_estimators=100) #RF is a random algorithm, so to get the same results we need to use random_state
rf18 = rf18.fit(X18_train, y18_train)

# %%
# K-Nearest neighbor
from sklearn.neighbors import KNeighborsRegressor #the object class we need

knn18 = KNeighborsRegressor(n_neighbors=5) #create a KNN-classifier with 5 neighbors (default)
knn18 = knn18.fit(X18_train, y18_train) #this fits the k-nearest neigbor model with the train data

# %% [markdown]
# ### Train the model for 2019

# %%
# Define X and y variables
X19 = X_odds_2019
y19 = y_odds_2019

X19_train, X19_test, y19_train, y19_test = train_test_split(X19, y19, test_size=0.3, random_state=1) #split the data, store it into different variables
X19_train.head()
# Out:
#     YOU WIN  BOYLE SPORTS  CORAL  SKY BET  BET VICTOR  TITAN BET    PAF  \
# 4      15.0          12.0    5.0     17.0        15.0       15.0   17.0
# 2       6.0           8.0   21.0     13.0        11.0       11.0    6.0
# 21    751.0         251.0  201.0    300.0       201.0      201.0  301.0
# 6      34.0          23.0    9.0     33.0        51.0       51.0   34.0
# 14    501.0         151.0   81.0    200.0       151.0      151.0   81.0
#
#     BETFAIR SPORT  SPORTING BET  INTERTOPS  PADDY POWER  BET FRED  BETWAY  \
# 4            21.0          11.0       15.0         21.0      15.0    19.0
# 2             7.5           8.0        8.0         11.0       9.0     8.5
# 21          301.0         301.0      200.0        251.0     201.0   201.0
# 6            31.0          26.0       20.0         41.0      21.0    34.0
# 14          151.0         201.0      150.0        251.0     201.0   126.0
#
#     STAN JAMES   BWIN  MATCHBOOK  BETFAIR* EXCHANGE  BETFAIR* EXCHANGE 2
# 4         14.0   21.0       19.0               21.0                 19.0
# 2          7.0   11.0        8.5               10.0                 14.0
# 21       250.0  101.0      201.0              151.0                700.0
# 6         25.0   51.0       34.0               34.0                 48.0
# 14       100.0  101.0      126.0              101.0                430.0

# %%
# TRAIN THE MODEL
rf19 = RandomForestRegressor(random_state=1, n_estimators=100) #RF is a random algorithm, so to get the same results we need to use random_state
rf19 = rf19.fit(X19_train, y19_train)

# %%
# K-Nearest neighbor
from sklearn.neighbors import KNeighborsRegressor #the object class we need

knn19 = KNeighborsRegressor(n_neighbors=5) #create a KNN-classifier with 5 neighbors (default)
knn19 = knn19.fit(X19_train, y19_train) #this fits the k-nearest neigbor model with the train data

# %% [markdown]
# ### Train the model for 2021

# %%
# Define X and y variables
X21 = X_odds_2021
y21 = y_odds_2021

X21_train, X21_test, y21_train, y21_test = train_test_split(X21, y21, test_size=0.3, random_state=1) #split the data, store it into different variables
X21_train.head()
# Out:
#     YOU WIN  BOYLE SPORTS  CORAL  SKY BET  BET VICTOR  TITAN BET     PAF  \
# 6      15.0          16.0    9.0     11.0        21.0       13.0   11.00
# 4       5.0           6.0    4.5      5.0         5.5        5.0    4.75
# 23    751.0         301.0  201.0    501.0       301.0      601.0  751.00
# 8      17.0          16.0   21.0     21.0        17.0       17.0   21.00
# 16    101.0         126.0  101.0    126.0       201.0      101.0  126.00
#
#     BETFAIR SPORT  SPORTING BET  INTERTOPS  PADDY POWER  BET FRED  BETWAY  \
# 6             8.5           8.0       11.0         14.0      26.0    10.0
# 4             5.1           5.0        4.5          6.0       5.5     5.0
# 23          500.0         500.0      251.0        301.0     501.0   100.0
# 8            18.0          20.0       15.0         16.0      19.0    16.0
# 16          150.0         200.0      151.0        126.0     101.0   100.0
#
#     STAN JAMES   BWIN  MATCHBOOK  BETFAIR* EXCHANGE  BETFAIR* EXCHANGE 2
# 6         13.0    9.0       11.0               16.0                 67.0
# 4          5.0    5.0        4.5                5.3                  5.0
# 23        67.0  101.0      101.0              500.0                151.0
# 8         17.0   17.0       17.0               18.0                 13.0
# 16        81.0  151.0      101.0              140.0                101.0

# %%
# TRAIN THE MODEL
rf21 = RandomForestRegressor(random_state=1, n_estimators=100) #RF is a random algorithm, so to get the same results we need to use random_state
rf21 = rf21.fit(X21_train, y21_train)

# %%
# K-Nearest neighbor
from sklearn.neighbors import KNeighborsRegressor #the object class we need

knn21 = KNeighborsRegressor(n_neighbors=5) #create a KNN-classifier with 5 neighbors (default)
knn21 = knn21.fit(X21_train, y21_train) #this fits the k-nearest neigbor model with the train data

# %% [markdown]
# ## Evaluation
# - evaluate the model: numerically, qualitatively and in terms of practical value.

# %% [markdown]
# ### Eurovision Songcontest 2015

# %% [markdown]
# ### <font color='green'>Evaluating the RF model

# %%
# Make a tree
from sklearn.datasets import load_boston
from sklearn import tree
from dtreeviz.trees import dtreeviz # will be used for tree visualization
import matplotlib.pyplot as plt

plt.rcParams.update({'figure.figsize': (12.0, 8.0)})
plt.rcParams.update({'font.size': 16})

# %%
tree.plot_tree(rf15.estimators_[0], feature_names=X15.columns, filled=True, fontsize=10)
# Out:
# [Text(315.1058823529412, 398.64, 'BOYLE SPORTS <= 91.0\nmse = 60.127\nsamples = 12\nvalue = 14.389'),
#  Text(157.5529411764706, 326.15999999999997, 'PADDY POWER <= 35.0\nmse = 18.81\nsamples = 6\nvalue = 8.7'),
#  Text(78.7764705882353, 253.67999999999998, 'PAF <= 14.75\nmse = 6.4\nsamples = 4\nvalue = 5.0'),
#  Text(39.38823529411765, 181.2, 'mse = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(118.16470588235295, 181.2, 'UNIBET <= 27.0\nmse = 0.667\nsamples = 3\nvalue = 7.0'),
#  Text(78.7764705882353, 108.71999999999997, 'mse = 0.0\nsamples = 1\nvalue = 6.0'),
#  Text(157.5529411764706, 108.71999999999997, 'BETFAIR* EXCHANGE <= 57.0\nmse = 0.25\nsamples = 2\nvalue = 7.5'),
#  Text(118.16470588235295, 36.23999999999995, 'mse = 0.0\nsamples = 1\nvalue = 7.0'),
#  Text(196.94117647058823, 36.23999999999995, 'mse = 0.0\nsamples = 1\nvalue = 8.0'),
#  Text(236.3294117647059, 253.67999999999998, 'STAN JAMES <= 46.0\nmse = 3.84\nsamples = 2\nvalue = 12.4'),
#  Text(196.94117647058823, 181.2, 'mse = 0.0\nsamples = 1\nvalue = 10.0'),
#  Text(275.71764705882356, 181.2, 'mse = 0.0\nsamples = 1\nvalue = 14.0'),
#  Text(472.6588235294118, 326.15999999999997, 'BET365 <= 176.0\nmse = 20.75\nsamples = 6\nvalue = 21.5'),
#  Text(393.88235294117646, 253.67999999999998, 'SKY BET <= 113.5\nmse = 2.688\nsamples = 3\nvalue = 17.25'),
#  Text(354.49411764705883, 181.2, 'CORAL <= 138.5\nmse = 0.222\nsamples = 2\nvalue = 16.333'),
#  Text(315.1058823529412, 108.71999999999997, 'mse = 0.0\nsamples = 1\nvalue = 16.0'),
#  Text(393.88235294117646, 108.71999999999997, 'mse = 0.0\nsamples = 1\nvalue = 17.0'),
#  Text(433.27058823529416, 181.2, 'mse = 0.0\nsamples = 1\nvalue = 20.0'),
#  Text(551.4352941176471, 253.67999999999998, 'PADDY POWER <= 126.0\nmse = 2.688\nsamples = 3\nvalue = 25.75'),
#  Text(512.0470588235295, 181.2, 'mse = 0.0\nsamples = 1\nvalue = 23.0'),
#  Text(590.8235294117648, 181.2, 'SKY BET <= 226.0\nmse = 0.222\nsamples = 2\nvalue = 26.667'),
#  Text(551.4352941176471, 108.71999999999997, 'mse = 0.0\nsamples = 1\nvalue = 27.0'),
#  Text(630.2117647058824, 108.71999999999997, 'mse = 0.0\nsamples = 1\nvalue = 26.0')]

# %%
# Import the libraries we need to create graphs
import matplotlib.pyplot as plt
import seaborn as sns

# %%
y15_pred = rf15.predict(X15_test) # The predicted values

# %%
# Mean Absolute Error
from sklearn.metrics import mean_absolute_error
mean_abs_err15 = mean_absolute_error(y15_test, y15_pred)

# Mean absolute error
print('Mean Absolute Error:', mean_abs_err15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-197-88d199c5bf65> in <module>
#       4
#       5 # Mean absolute error
# ----> 6 print('Mean Absolute Error:', mean_abs_err)
#
# NameError: name 'mean_abs_err' is not defined

# %%
from sklearn.metrics import explained_variance_score
# Explained Variance Score
y15_pred = rf16.predict(X15_test) #the predicted values
evs = explained_variance_score(y15_test, y15_pred)
print("Explained Variance Score:", evs)
# Out:
# Explained Variance Score: 0.9222659019812305

# %%
# Max Error
from sklearn.metrics import max_error
max_err = max_error(y15_test, y15_pred)
print("Max Error:", max_err)
# Out:
# Max Error: 6.199999999999999

# %%
# Mean Squard Error
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y15_test, y15_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 15.79173333333333

# %%
# Mean Squared Logarithmic Error
from sklearn.metrics import mean_squared_log_error
msel = mean_squared_log_error(y15_test, y15_pred)
print("Mean Squared Logarithmic Error:", msel)
# Out:
# Mean Squared Logarithmic Error: 0.07163354446291245

# %%
# R2 SCORE
from sklearn.metrics import r2_score
r2 = r2_score(y15_test, y15_pred)
print("R2 score:", r2)
# Out:
# R2 score: 0.6665457768508865

# %%
# Calculate mean absolute percentage error (MAPE)
mape15 = 100 * (mean_abs_err15 / y15_test)# Calculate and display accuracy
accuracy15 = 100 - np.mean(mape15)
print('Accuracy:', round(accuracy15, 2), '%.')
# Out:
# Accuracy: 90.06 %.

# %% [markdown]
# The random forest model can predicts 90.06% of the actual positions.

# %% [markdown]
# ### <font color='orange'>Evaluating K-nearest neighbor

# %%
score15 = knn15.score(X15_test, y15_test) #calculate the fit on the test data
score15
# Out:
# 0.8325755995828988

# %% [markdown]
# We can predict **90.06%** of the positions based on the odds given by bookmakers with the **Random Forest** algorithm. The K-nearest neighbor algorithm predicted **83.26%** right.

# %% [markdown]
# ### <font color="purple">Refine with log

# %%
# X15L_test.dtypes
# X15L_test  = X15L_test.replace('', np.nan_to_num(0), regex=True)
# X15L_test[~X15L_test.isin([np.nan, np.inf, -np.inf]).any(1)] # Remove inf

# %%
# y15L_pred = rf15L.predict(X15L_test) # The predicted values

# %%
# # Mean Absolute Error
# from sklearn.metrics import mean_absolute_error
# mean_abs_err15L = mean_absolute_error(y15L_test, y15L_pred)

# # Mean absolute error
# print('Mean Absolute Error:', mean_abs_err15L)

# %%
# # Calculate mean absolute percentage error (MAPE)
# mape15L = 100 * (mean_abs_err15L / y15L_test)# Calculate and display accuracy
# accuracy = 100 - np.mean(mape15L)
# print('Accuracy:', round(accuracy, 2), '%.')

# %%
# knnL.score(X15L_test, y15L_test) #calculate the fit on the test data

# %% [markdown]
# ### Eurovision Songcontest 2016

# %%
y16_pred = rf16.predict(X16_test) # The predicted values

mean_abs_err16 = mean_absolute_error(y16_test, y16_pred)

# Mean absolute error
print('The mean absolute error is:', mean_abs_err)
# Out:
# The mean absolute error is: 1.2737500000000002

# %%
# Calculate mean absolute percentage error (MAPE)
mape16 = 100 * (mean_abs_err16 / y16_test)# Calculate and display accuracy
accuracy16 = 100 - np.mean(mape16)
print('Accuracy:', round(accuracy16, 2), '%.')
# Out:
# Accuracy: 89.47 %.

# %%
score16 = knn16.score(X16_test, y16_test) #calculate the fit on the test data
score16
# Out:
# 0.852196007259528

# %% [markdown]
# **K-Nearest neighbor** has a slightly better prediction for this year (2016): **92.07%** in contrast to **89.47%** for the Random Forest algorithm.

# %% [markdown]
# ### Eurovision Songcontest 2017

# %%
y17_pred = rf17.predict(X17_test) # The predicted values

mean_abs_err17 = mean_absolute_error(y17_test, y17_pred)

# Mean absolute error
print('The mean absolute error is:', mean_abs_err17)
# Out:
# The mean absolute error is: 1.06375

# %%
# Calculate mean absolute percentage error (MAPE)
mape17 = 100 * (mean_abs_err17 / y17_test)# Calculate and display accuracy
accuracy17 = 100 - np.mean(mape17)
print('Accuracy:', round(accuracy17, 2), '%.')
# Out:
# Accuracy: 91.2 %.

# %%
score17 = knn17.score(X17_test, y17_test) #calculate the fit on the test data
score17
# Out:
# 0.8324500907441017

# %% [markdown]
# The **Random Forest** algorithm predicts about **91.2%** right. K-Nearest Neighbor predicts about **83.26%** right. There's a larger difference between the K-Nearest Neighbor algorithm and the Random Forest algorithm compared to the years 2015 and 2016.

# %% [markdown]
# ### Eurovision Songcontest 2018

# %%
y18_pred = rf18.predict(X18_test) # The predicted values

mean_abs_err18 = mean_absolute_error(y18_test, y18_pred)

# Mean absolute error
print('The mean absolute error is:', mean_abs_err18)
# Out:
# The mean absolute error is: 1.1725

# %%
# Calculate mean absolute percentage error (MAPE)
mape18 = 100 * (mean_abs_err18 / y18_test)# Calculate and display accuracy
accuracy18 = 100 - np.mean(mape18)
print('Accuracy:', round(accuracy18, 2), '%.')
# Out:
# Accuracy: 90.3 %.

# %%
score18 = knn18.score(X18_test, y18_test) #calculate the fit on the test data
score18
# Out:
# 0.806896551724138

# %% [markdown]
# The **Random Forest** algorithm predicts about **90.3%** right. K-Nearest Neighbor predicts about **80.69%** right. There's a larger difference between the K-Nearest Neighbor algorithm and the Random Forest algorithm compared to the years 2015 and 2016. The difference is about 10%.

# %% [markdown]
# ### Eurovision Songcontest 2019

# %%
y19_pred = rf19.predict(X19_test) # The predicted values

mean_abs_err19 = mean_absolute_error(y19_test, y19_pred)

# Mean absolute error
print('The mean absolute error is:', mean_abs_err19)
# Out:
# The mean absolute error is: 0.7637499999999997

# %%
# Calculate mean absolute percentage error (MAPE)
mape19 = 100 * (mean_abs_err19 / y19_test)# Calculate and display accuracy
accuracy19 = 100 - np.mean(mape19)
print('Accuracy:', round(accuracy19, 2), '%.')
# Out:
# Accuracy: 93.68 %.

# %%
score19 = knn19.score(X19_test, y19_test) #calculate the fit on the test data
score19
# Out:
# 0.9544101633393829

# %% [markdown]
# For this year (2019), there's a decrease in the difference between the two algorithms. The Random Forest algorithm predicts about **93.68%** correct. The **K-Nearest Neighbor** algorithm predicts about **95.44%** percent right.

# %% [markdown]
# ### Eurovsion Songcontest 2021

# %%
y21_pred = rf21.predict(X21_test) # The predicted values

mean_abs_err21 = mean_absolute_error(y21_test, y21_pred)

# Mean absolute error
print('The mean absolute error is:', mean_abs_err21)
# Out:
# The mean absolute error is: 0.9175000000000003

# %%
# Calculate mean absolute percentage error (MAPE)
mape21 = 100 * (mean_abs_err21 / y21_test)# Calculate and display accuracy
accuracy21 = 100 - np.mean(mape21)
print('Accuracy:', round(accuracy21, 2), '%.')
# Out:
# Accuracy: 92.41 %.

# %%
score21 = knn21.score(X21_test, y21_test) #calculate the fit on the test data
score21
# Out:
# 0.8697640653357531

# %% [markdown]
# For this year (2021), the **Random Forest** algorithm performs clearly better. The accuracy is about **92.41%**, while the K-Nearesy Neighbor score is **86.98**.

# %% [markdown]
# ## Conclusion

# %%
mean_rf = np.mean([[accuracy15], [accuracy16], [accuracy17], [accuracy18], [accuracy19], [accuracy21]])
mean_rf
# Out:
# 91.18723187038813

# %%
mean_knn = np.mean([[score15], [score16], [score17], [score18], [score19], [score21]])
mean_knn
# Out:
# 0.8580487463309671

# %% [markdown]
# The **Random Forest** algorithm is a better predictor for reviewing how good odd bets can predict the final position.

# %% [markdown]
# #### How good were the bookmakers in guessing who won the Eurovision Songcontest?

# %%
# Import the libraries for creating plots
import matplotlib.pyplot as plt
import seaborn as sns

Year = [2015, 2016, 2017, 2018, 2019, 2021]
Prediction_rf = [accuracy15, accuracy16, accuracy17, accuracy18, accuracy19, accuracy21]
Prediction_knn = [score15 * 100, score16 * 100, score17 * 100, score18 * 100, score19 * 100, score21 * 100] 


data_plot = pd.DataFrame({"Year":Year, "Percentage correct (%)":Prediction_rf})
data_plot2 = pd.DataFrame({"Year":Year, "Percentage correct (%)":Prediction_knn})


sns.lineplot(x = "Year", y = "Percentage correct (%)", data=data_plot, color="green")
sns.lineplot(x = "Year", y = "Percentage correct (%)", data=data_plot2, color="orange")
plt.legend(labels=['Random Forest', 'K-Nearest Nwighbor'])
plt.show()

# %% [markdown]
# ## References (optional)
# - any literature referenced in APA style. Code snippets need not be referenced, but see Use of sources and plagiarism below.
